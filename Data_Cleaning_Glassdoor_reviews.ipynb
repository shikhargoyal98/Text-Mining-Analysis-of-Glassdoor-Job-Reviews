# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#display all column
pd.set_option('display.max_columns', None)

# %%
#Reading the dataset
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviews.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838566 entries, 0 to 838565
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   firm                 838566 non-null  object
#  1   date_review          838566 non-null  object
#  2   job_title            838566 non-null  object
#  3   current              838566 non-null  object
#  4   location             541223 non-null  object
#  5   overall_rating       838566 non-null  int64
#  6   work_life_balance    688672 non-null  float64
#  7   culture_values       647193 non-null  float64
#  8   diversity_inclusion  136066 non-null  float64
#  9   career_opp           691065 non-null  float64
#  10  comp_benefits        688484 non-null  float64
#  11  senior_mgmt          682690 non-null  float64
#  12  recommend            838566 non-null  object
#  13  ceo_approv           838566 non-null  object
# ...

# %%
df1.firm.value_counts()
# Out:
# firm
# IBM                         60436
# McDonald-s                  49450
# Deloitte                    46995
# EY                          34050
# PwC                         33227
#                             ...
# Health-Protection-Agency        4
# i-Net-Solution                  4
# The-Survey-Association          3
# NPSA                            2
# UKCIL                           1
# Name: count, Length: 428, dtype: int64

# %%
df2 = pd.DataFrame(df1.firm.value_counts())
df2.head(10)
# Out:
#             count
# firm
# IBM         60436
# McDonald-s  49450
# Deloitte    46995
# EY          34050
# PwC         33227
# Oracle      31941
# Microsoft   26675
# J-P-Morgan  25814
# KPMG        24815
# Apple       20797

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# firm                    0.000000
# date_review             0.000000
# job_title               0.000000
# current                 0.000000
# location               35.458509
# overall_rating          0.000000
# work_life_balance      17.875039
# culture_values         22.821459
# diversity_inclusion    83.773967
# career_opp             17.589671
# comp_benefits          17.897458
# senior_mgmt            18.588400
# recommend               0.000000
# ceo_approv              0.000000
# outlook                 0.000000
# headline                0.308861
# pros                    0.000239
# cons                    0.001550
# dtype: float64

# %%
df3 = df1[df1['firm'] == 'IBM']
df3.head()
# Out:
#        firm date_review                  job_title           current  \
# 341409  IBM  2008-05-30               IT Architect  Current Employee
# 341410  IBM  2008-06-01   Senior Software Engineer  Current Employee
# 341411  IBM  2008-06-03              IT Specialist  Current Employee
# 341412  IBM  2008-06-03                      Sales  Current Employee
# 341413  IBM  2008-06-05       Education Consultant  Current Employee
#
#                   location  overall_rating  work_life_balance  culture_values  \
# 341409  Essex Junction, VT               4                5.0             NaN
# 341410    Poughkeepsie, NY               5                5.0             NaN
# 341411        New York, NY               5                4.0             NaN
# 341412         Toronto, ON               5                5.0             NaN
# 341413         Atlanta, GA               3                2.0             NaN
#
#         diversity_inclusion  career_opp  comp_benefits  senior_mgmt recommend  \
# ...

# %%
df3['overall_rating'].value_counts()/len(df3)*100 #IBM
# Out:
# overall_rating
# 4    34.074062
# 3    28.271229
# 5    20.630088
# 2    10.872659
# 1     6.151962
# Name: count, dtype: float64

# %%
#IBM, Apple), food (McDonald's), and consulting (Deloitte).

# %%
df5 = df1[df1['firm'] == 'McDonald-s' ]
df5.head()
# Out:
#               firm date_review         job_title           current  \
# 503785  McDonald-s  2008-09-18     Store Manager  Current Employee
# 503786  McDonald-s  2008-09-19   Cook, Fast Food  Current Employee
# 503787  McDonald-s  2008-09-19      Crew Trainer  Current Employee
# 503788  McDonald-s  2008-09-25           Cashier  Current Employee
# 503789  McDonald-s  2008-09-25      Head Office   Current Employee
#
#              location  overall_rating  work_life_balance  culture_values  \
# 503785   Columbus, OH               4                3.0             NaN
# 503786     Mercer, PA               1                1.0             NaN
# 503787  Green Bay, WI               4                2.0             NaN
# 503788            NaN               2                3.0             NaN
# 503789    Toronto, ON               4                2.0             NaN
#
#         diversity_inclusion  career_opp  comp_benefits  senior_mgmt recommend  \
# ...

# %%
df5['overall_rating'].value_counts()/len(df5)*100 # Mcdonalds
# Out:
# overall_rating
# 3    31.456016
# 4    25.306370
# 5    20.038423
# 2    12.841254
# 1    10.357937
# Name: count, dtype: float64

# %%
df6 = df1[df1['firm'] == 'Apple' ]
df6.head()
df6['overall_rating'].value_counts()/len(df6)*100
# Out:
# overall_rating
# 5    41.996442
# 4    33.278838
# 3    15.910949
# 2     5.197865
# 1     3.615906
# Name: count, dtype: float64

# %%
df7 = df1[df1['firm'] == 'Deloitte' ]
df7.head()
df7['overall_rating'].value_counts()/len(df7)*100
# Out:
# overall_rating
# 4    40.832003
# 5    25.926162
# 3    22.617300
# 2     6.560272
# 1     4.064262
# Name: count, dtype: float64

# %%
''' EY	34050
PwC	33227
Oracle	31941
Microsoft	26675
J-P-Morgan	25814
KPMG	24815 '''
# Out:
# ' EY\t34050\nPwC\t33227\nOracle\t31941\nMicrosoft\t26675\nJ-P-Morgan\t25814\nKPMG\t24815 '

# %%
df8 = df1[df1['firm'] == 'EY' ]
df8.head()
df8['overall_rating'].value_counts()/len(df8)*100
# Out:
# overall_rating
# 4    41.089574
# 3    24.464023
# 5    23.665198
# 2     6.716593
# 1     4.064611
# Name: count, dtype: float64

# %%
df9 = df1[df1['firm'] == 'PwC' ]
df9.head()
df9['overall_rating'].value_counts()/len(df9)*100
# Out:
# overall_rating
# 4    40.867367
# 5    24.549312
# 3    23.881181
# 2     6.545881
# 1     4.156258
# Name: count, dtype: float64

# %%
df10 = df1[df1['firm'] == 'Oracle' ]
df10.head()
df10['overall_rating'].value_counts()/len(df10)*100
# Out:
# overall_rating
# 4    35.333897
# 3    31.674024
# 5    16.383332
# 2    10.832472
# 1     5.776275
# Name: count, dtype: float64

# %%
df11 = df1[df1['firm'] == 'Microsoft' ]
df11['overall_rating'].value_counts()/len(df11)*100
# Out:
# overall_rating
# 4    36.903468
# 5    36.371134
# 3    17.668229
# 2     5.866917
# 1     3.190253
# Name: count, dtype: float64

# %%
df12 = df1[df1['firm'] == 'J-P-Morgan' ]
df12['overall_rating'].value_counts()/len(df12)*100
# Out:
# overall_rating
# 4    36.518943
# 5    26.524367
# 3    23.770047
# 2     8.049895
# 1     5.136748
# Name: count, dtype: float64

# %%
df13 = df1[df1['firm'] == 'KPMG' ]
df13['overall_rating'].value_counts()/len(df13)*100
# Out:
# overall_rating
# 4    40.556115
# 3    26.165626
# 5    21.212976
# 2     7.539794
# 1     4.525489
# Name: count, dtype: float64

# %%
#IBM, MCD, #JP MORGAN, #ORACLE

# %%
df1.head()
# Out:
#                     firm date_review              job_title  \
# 0  AFH-Wealth-Management  2015-04-05
# 1  AFH-Wealth-Management  2015-12-11   Office Administrator
# 2  AFH-Wealth-Management  2016-01-28   Office Administrator
# 3  AFH-Wealth-Management  2016-04-16
# 4  AFH-Wealth-Management  2016-04-23   Office Administrator
#
#                               current                      location  \
# 0                    Current Employee                           NaN
# 1  Current Employee, more than 1 year  Bromsgrove, England, England
# 2  Current Employee, less than 1 year  Bromsgrove, England, England
# 3                    Current Employee                           NaN
# 4  Current Employee, more than 1 year  Bromsgrove, England, England
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion  \
# 0               2                4.0             3.0                  NaN
# 1               2                3.0             1.0                  NaN
# ...

# %%
# df12,df10,df5,df3

# %%
print(df3.isnull().sum()/len(df3)*100) #IBM
#print(df5.isnull().sum()/len(df5)*100)
#print(df10.isnull().sum()/len(df10)*100)
#print(df12.isnull().sum()/len(df12)*100)
#
# Out:
# firm                    0.000000
# date_review             0.000000
# job_title               0.000000
# current                 0.000000
# location               36.200278
# overall_rating          0.000000
# work_life_balance      14.842147
# culture_values         23.368522
# diversity_inclusion    86.279701
# career_opp             14.704812
# comp_benefits          14.855384
# senior_mgmt            15.575154
# recommend               0.000000
# ceo_approv              0.000000
# outlook                 0.000000
# headline                0.311073
# pros                    0.000000
# cons                    0.000000
# dtype: float64

# %%
print(df5.isnull().sum()/len(df5)*100) #Mcdonalds
# Out:
# firm                    0.000000
# date_review             0.000000
# job_title               0.000000
# current                 0.000000
# location               43.330637
# overall_rating          0.000000
# work_life_balance      29.516684
# culture_values         31.856421
# diversity_inclusion    80.972700
# career_opp             28.463094
# comp_benefits          29.468150
# senior_mgmt            30.709808
# recommend               0.000000
# ceo_approv              0.000000
# outlook                 0.000000
# headline                0.323559
# pros                    0.000000
# cons                    0.000000
# dtype: float64

# %%
print(df10.isnull().sum()/len(df10)*100) #Oracle
# Out:
# firm                    0.000000
# date_review             0.000000
# job_title               0.000000
# current                 0.000000
# location               36.382706
# overall_rating          0.000000
# work_life_balance      15.074669
# culture_values         21.530322
# diversity_inclusion    87.035472
# career_opp             15.084061
# comp_benefits          15.018315
# senior_mgmt            15.647600
# recommend               0.000000
# ceo_approv              0.000000
# outlook                 0.000000
# headline                0.269246
# pros                    0.000000
# cons                    0.000000
# dtype: float64

# %%
print(df12.isnull().sum()/len(df12)*100) #JPMorgan
# Out:
# firm                    0.000000
# date_review             0.000000
# job_title               0.000000
# current                 0.000000
# location               35.368405
# overall_rating          0.000000
# work_life_balance      17.874022
# culture_values         24.021849
# diversity_inclusion    84.806694
# career_opp             17.722941
# comp_benefits          17.812040
# senior_mgmt            18.493841
# recommend               0.000000
# ceo_approv              0.000000
# outlook                 0.000000
# headline                0.402882
# pros                    0.000000
# cons                    0.000000
# dtype: float64

# %%
#exporting data to drive
df12.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf12.csv')

# %%
#exporting data to drive
df10.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf10.csv')

# %%
#exporting data to drive
df5.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf5.csv')

# %%
#exporting data to drive
df3.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf3.csv')

# %%
L1 = ['firm',
    'overall_rating',
    'pros',
    'cons',
    'headline',
    'recommend',
    'ceo_approv',
    'outlook',
    'current',
    'job_title',
    'date_review',
    'work_life_balance',
    'culture_values',
    'career_opp',
    'comp_benefits',
    'senior_mgmt'
]

# %%
df5= df5[L1]
df5.head()
# Out:
#               firm  overall_rating  \
# 503785  McDonald-s               4
# 503786  McDonald-s               1
# 503787  McDonald-s               4
# 503788  McDonald-s               2
# 503789  McDonald-s               4
#
#                                                      pros  \
# 503785  The vacation time is good.  After five years, ...
# 503786  If you need the moeny, it is better than selli...
# 503787  It was a great opportunity to work at while st...
# 503788  Conveniece and a good work experience. Usually...
# 503789  Team work is key.  Plan to Win is a great stra...
#
#                                                      cons  \
# 503785  Sometimes certain locations can be much worse ...
# 503786  Greasy skin, bad pay, terrible bosses, moronic...
# 503787  Just some of the people you worked with.  You ...
# 503788  Overworked compared to other kinds of food ret...
# 503789  Salary and benefits are just average.  Workloa...
#
# ...

# %%
df3= df3[L1]
df3.head()
# Out:
#        firm  overall_rating  \
# 341409  IBM               4
# 341410  IBM               5
# 341411  IBM               5
# 341412  IBM               5
# 341413  IBM               3
#
#                                                      pros  \
# 341409  Availability of information resources to help ...
# 341410  IBM is a large company with a lot of great peo...
# 341411  IBM has a very structured approach to personal...
# 341412  Quality of the people I work with and the rewa...
# 341413  IBM is the largest education provider in the i...
#
#                                                      cons  \
# 341409  Politically correct (PC) version of diversity ...
# 341410  It is a large company, and this isn't for ever...
# 341411  The main negative about working for IBM is tie...
# 341412  The breadth of the value we can provide our cu...
# 341413  Excessive hours. Mandatory travel. Persons who...
#
#                                                  headline recommend  \
# ...

# %%
df10= df10[L1]
df10.head()
# Out:
#           firm  overall_rating  \
# 615202  Oracle               3
# 615203  Oracle               4
# 615204  Oracle               3
# 615205  Oracle               4
# 615206  Oracle               1
#
#                                                      pros  \
# 615202  Incredible opportunity for growth within compa...
# 615203  One of the best things about working here is t...
# 615204  Benefits - one of the most comprehensive benef...
# 615205  Flexible work arrangements.  Equitable compens...
# 615206  Oracle allows you to work from anywhere as lon...
#
#                                                      cons  \
# 615202  There are too few employees. Often we have to ...
# 615203  The fact that we have layoffs about every 2 ye...
# 615204  Too big at times - you have to deal with a num...
# 615205  I was part of the PeopleSoft takeover.  Oracle...
# 615206         There are many! slave labor comes to mind!
#
# ...

# %%
df12= df12[L1]
df12.head()
# Out:
#               firm  overall_rating  \
# 408410  J-P-Morgan               4
# 408411  J-P-Morgan               5
# 408412  J-P-Morgan               4
# 408413  J-P-Morgan               4
# 408414  J-P-Morgan               2
#
#                                                      pros  \
# 408410  Good compensation package and some of the smar...
# 408411  It is a wonderful place to network and meet pe...
# 408412  The Benefits at Chase are top notch.  The work...
# 408413  The Private Bank, under Asset Management has d...
# 408414  Leader in the financial industry\r\nGlobal rea...
#
#                                                      cons  \
# 408410  Very long hours, and at times when work just p...
# 408411  At times, working for a big company like this,...
# 408412  Some of the downsides are probably working for...
# 408413  It is a large scale company, and while this cr...
# 408414  Senior management incapable of managing around...
#
# ...

# %%
print(df3.isnull().sum()) #IBM


print(df5.isnull().sum()) #Mcdonalds


print(df10.isnull().sum()) #Oracle


print(df12.isnull().sum()) #JPMorgan
# Out:
# firm                     0
# overall_rating           0
# pros                     0
# cons                     0
# headline               188
# recommend                0
# ceo_approv               0
# outlook                  0
# current                  0
# job_title                0
# date_review              0
# work_life_balance     8970
# culture_values       14123
# career_opp            8887
# comp_benefits         8978
# senior_mgmt           9413
# dtype: int64
# firm                     0
# overall_rating           0
# pros                     0
# cons                     0
# headline               160
# recommend                0
# ceo_approv               0
# outlook                  0
# current                  0
# job_title                0
# date_review              0
# work_life_balance    14596
# culture_values       15753
# career_opp           14075
# comp_benefits        14572
# senior_mgmt          15186
# dtype: int64
# firm                    0
# ...

# %%
for col in ['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']:
    df3[f'{col}_missing'] = df3[col].isna().astype(int)
    df3[col].fillna(3, inplace=True)  # Neutral imputation
# Out:
# <ipython-input-101-ccc2bc92787b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3[col].fillna(3, inplace=True)  # Neutral imputation
# <ipython-input-101-ccc2bc92787b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
for col in ['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']:
    df5[f'{col}_missing'] = df5[col].isna().astype(int)
    df5[col].fillna(3, inplace=True)  # Neutral imputation
# Out:
# <ipython-input-102-383a4eea8dca>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df5[col].fillna(3, inplace=True)  # Neutral imputation
# <ipython-input-102-383a4eea8dca>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
for col in ['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']:
    df10[f'{col}_missing'] = df10[col].isna().astype(int)
    df10[col].fillna(3, inplace=True)  # Neutral imputation
# Out:
# <ipython-input-103-03da17d71678>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df10[col].fillna(3, inplace=True)  # Neutral imputation
# <ipython-input-103-03da17d71678>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
for col in ['work_life_balance', 'culture_values', 'career_opp', 'comp_benefits', 'senior_mgmt']:
    df12[f'{col}_missing'] = df12[col].isna().astype(int)
    df12[col].fillna(3, inplace=True)  # Neutral imputation
# Out:
# <ipython-input-104-d2b80f9a03c9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df12[col].fillna(3, inplace=True)  # Neutral imputation
# <ipython-input-104-d2b80f9a03c9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Define the code-to-label mapping
sentiment_map = {
    'v': 'Positive',
    'r': 'Mild',
    'x': 'Negative',
    'o': 'No opinion'
}

# Apply to each column
df3['recommend_label'] = df3['recommend'].map(sentiment_map)
df3['ceo_approv_label'] = df3['ceo_approv'].map(sentiment_map)
df3['outlook_label'] = df3['outlook'].map(sentiment_map)

# %%
# Define the code-to-label mapping
sentiment_map = {
    'v': 'Positive',
    'r': 'Mild',
    'x': 'Negative',
    'o': 'No opinion'
}

# Apply to each column
df5['recommend_label'] = df5['recommend'].map(sentiment_map)
df5['ceo_approv_label'] = df5['ceo_approv'].map(sentiment_map)
df5['outlook_label'] = df5['outlook'].map(sentiment_map)

# %%
# Define the code-to-label mapping
sentiment_map = {
    'v': 'Positive',
    'r': 'Mild',
    'x': 'Negative',
    'o': 'No opinion'
}

# Apply to each column
df10['recommend_label'] = df10['recommend'].map(sentiment_map)
df10['ceo_approv_label'] = df10['ceo_approv'].map(sentiment_map)
df10['outlook_label'] = df10['outlook'].map(sentiment_map)

# %%
# Define the code-to-label mapping
sentiment_map = {
    'v': 'Positive',
    'r': 'Mild',
    'x': 'Negative',
    'o': 'No opinion'
}

# Apply to each column
df12['recommend_label'] = df12['recommend'].map(sentiment_map)
df12['ceo_approv_label'] = df12['ceo_approv'].map(sentiment_map)
df12['outlook_label'] = df12['outlook'].map(sentiment_map)

# %%
df3.drop(['recommend', 'ceo_approv', 'outlook'], axis=1, inplace=True)
df5.drop(['recommend', 'ceo_approv', 'outlook'], axis=1, inplace=True)
df10.drop(['recommend', 'ceo_approv', 'outlook'], axis=1, inplace=True)
df12.drop(['recommend', 'ceo_approv', 'outlook'], axis=1, inplace=True)

# %%
#exporting data to drive
df12.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf12.csv')

# %%
#exporting data to drive
df10.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf10.csv')

# %%
#exporting data to drive
df3.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf3.csv')

# %%
#exporting data to drive
df5.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/glassdoor_reviewsdf5.csv')
